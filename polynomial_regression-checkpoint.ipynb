# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("Position_Salaries.csv")
X = data.iloc[:, 1:-1].values
y = data.iloc[:, -1].values

# %% [markdown]
# ## training linear reg model

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
# visualizing data
plt.scatter(X, y, color='red')
plt.plot(X, lr.predict(X), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## training polynomial reg model

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
# creating new matrix of features
X_poly = poly_reg.fit_transform(X)
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color='red')
plt.plot(X, lin_reg2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Truth or Bluff (polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %%
# better curve -> more x points
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color='red')
plt.plot(X_grid, lin_reg2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## predictions for single values

# %%
print(f"normal linear reg prediction for 6.5 - {lr.predict([[6.5]])}")
print(f"polynomial linear reg prediction for 6.5 - {lin_reg2.predict(poly_reg.fit_transform([[6.5]]))}")
# Out:
# normal linear reg prediction for 6.5 - [330378.78787879]
# polynomial linear reg prediction for 6.5 - [158862.45265157]
